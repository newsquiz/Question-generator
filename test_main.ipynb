# %%
from reading.reading_generator import ReadingGenerator
from listening.listening_generator import ListeningGenerator

# %%
reading_generator = ReadingGenerator()
listening_generator = ListeningGenerator()
# Out:
# 2019-08-08 23:31:33,584     INFO   59 corenlp:backend.__init__: Executing `java -Xms2g -Xmx3000m -cp /home/tittit/.enlp/data/corenlp/stanford-corenlp-3.8.0.jar:/home/tittit/.enlp/data/corenlp/stanford-corenlp-3.8.0-models.jar edu.stanford.nlp.pipeline.StanfordCoreNLP -props /home/tittit/.enlp/data/corenlp/english.properties`

# %%
document = "In 1947-48, Torino Motor scored 125 goals in their 40 matches, finishing with a record goal difference of +92 on their way their fourth title in as many seasons. By the time of the Superga disaster they had not lost at home in more than six years, while their 10-0 victory over Alessandria in May 1948 remains the biggest in Serie A history."
reading_questions = reading_generator.get_questions(document)
listening_questions = listening_generator.get_questions(document)
# Out:
# In 1947-48 , Torino Motor scored 125 goals in their 40 matches , finishing with a record goal difference of +92 on their way their fourth title in as many seasons .
# By the time of the Superga disaster Torino Motor had not lost at home in more than six years , while their 10-0 victory over Alessandria in May 1948 remains the biggest in Serie A history .
# ...

# %%
reading_questions
# Out:
# [{'answer': '125',
#   'explain': '',
#   'level': 'Easy',
#   'question': 'How many goals in their 40 matches did Torino Motor score?',
#   'question_type': 'Short-Answer-Question',
#   'sentence_index': 0,
#   'tags': ['nummod', 'reading-comprehension']},
#  {'answer': 'Torino Motor',
#   'explain': '',
#   'level': 'Easy',
#   'question': 'which organization scored 125 goals in their 40 matches , finishing with a record goal difference of +92 on their way their fourth title in as many seasons?',
#   'question_type': 'Short-Answer-Question',
#   'sentence_index': 0,
#   'tags': ['ORGANIZATION', 'subj', 'reading-comprehension']},
#  {'answer': '1947-48',
#   'explain': '',
#   'level': 'Easy',
#   'question': 'when did Torino Motor score  125 goals in their 40 matches?',
#   'question_type': 'Short-Answer-Question',
#   'sentence_index': 0,
#   'tags': ['DATE', 'nmod', 'reading-comprehension']},
#  {'answer': '125 goals in their 40 matches',
#   'explain': '',
#   'level': 'Easy',
# ...

# %%
listening_questions
# Out:
# [{'answer': 'scored',
#   'explain': '',
#   'level': 'Easy',
#   'question': ' In 1947-48 , Torino Motor _____ 125 goals in their 40 matches , finishing with a record goal difference of +92 on their way their fourth title in as many seasons .',
#   'question_type': 'Fullfill',
#   'sentence_index': 0,
#   'tags': ['homophone', 'phonetic']},
#  {'answer': 'scored',
#   'explain': '',
#   'level': 'Easy',
#   'list_choices': ['chord', 'scores', 'stored'],
#   'question': ' In 1947-48 , Torino Motor _____ 125 goals in their 40 matches , finishing with a record goal difference of +92 on their way their fourth title in as many seasons .',
#   'question_type': 'Fullfill-MultiChoice',
#   'sentence_index': 0,
#   'tags': ['homophone', 'phonetic']},
#  {'answer': 'matches',
#   'explain': '',
#   'level': 'Easy',
# ...
